# %% [markdown]
# # Compare genbank phages to prophages
#
# The genbank data comes from [the Cook et al paper](https://www.biorxiv.org/content/10.1101/2021.05.01.442102v1) and especially their [supplemental material](https://www.biorxiv.org/content/10.1101/2021.05.01.442102v1.supplementary-material)
#
# ```
# Cook R, Brown N, Redgwell T, Rihtman B, Barnes M, Stekel DJ, Clokie M, Hobman J, Jones M, Millard AD. 2021. INfrastructure for a PHAge REference Database: Identification of large-scale biases in the current collection of phage genomes. bioRxiv.
# ```

# %%
# A lot of this is not used, but we import it so we have it later!
import os
import sys
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from matplotlib.ticker import FuncFormatter

import pandas as pd
import seaborn as sns
import numpy as np

import math
import re
import string

from PhiSpyAnalysis import theils_u, DateConverter, printmd
from PhiSpyAnalysis import read_phages, read_gtdb, read_checkv, read_base_pp, read_categories, read_metadata, read_transposons

from scipy.stats import pearsonr, f_oneway
from sklearn.linear_model import LinearRegression
from sklearn import decomposition
from sklearn.ensemble import RandomForestClassifier

import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd, tukeyhsd, MultiComparison
from statsmodels.multivariate.manova import MANOVA

# %%
hosts = set()
with open('../data/Cook_unique_hosts.txt', 'r') as h:
    for l in h:
        if l.strip():
            hosts.add(l.strip())
hosts
# Out:
# {'Acaryochloris',
#  'Acholeplasma',
#  'Achromobacter',
#  'Acidianus',
#  'Acidithiobacillus',
#  'Acidovorax',
#  'Acinetobacter',
#  'Actinomyces',
#  'Actinoplanes',
#  'Aeribacillus',
#  'Aerococcus',
#  'Aeromonas',
#  'Aeropyrum',
#  'Aggregatibacter',
#  'Agrobacterium',
#  'Alteromonas',
#  'Aminobacter',
#  'Anabaena',
#  'Anoxybacillus',
#  'Aphanizomenon',
#  'Aquamicrobium',
#  'Arthrobacter',
#  'Arthronema',
#  'Aurantimonas',
#  'Azobacteroides',
#  'Azospirillum',
#  'Bacillus',
#  'Bacilus',
#  'Bacteroides',
#  'Bdellovibrio',
#  'Bifidobacterium',
#  'Bordetella',
#  'Bradyrhizobium',
#  'Brevibacillus',
#  'Brevibacterium',
#  'Brevundimonas',
#  'Brochothrix',
#  'Brucella',
#  'Burkholderia',
#  'Buttiauxella',
#  'Butyrivibrio',
#  'Caldibacillus',
#  'Campylobacter',
#  'Caulobacter',
#  'Celeribacter',
#  'Cellulophaga',
#  'Chlamydia',
#  'Citrobacter',
#  'Citromicrobium',
#  'Clavibacter',
#  'Clostridioides',
#  'Clostridium',
#  'Colwellia',
#  'Corynebacterium',
#  'Croceibacter',
#  'Cronobacter',
#  'Curvibacter',
#  'Cutibacterium',
#  'Cylindrospermopsis',
#  'Delftia',
#  'Dickeya',
#  'Dinoroseobacter',
#  'Dunaliella',
#  'Edwardsiella',
#  'Eggerthella',
#  'Elizabethkingia',
#  'Enterobacter',
#  'Enterobacteria',
#  'Enterococcus',
#  'Erwinia',
#  'Erysipelothrix',
#  'Erythrobacter',
#  'Escherichia',
#  'Exiguobacterium',
#  'Faecalibacterium',
#  'Flavobacterium',
#  'Fusobacterium',
#  'Gardnerella',
#  'Geobacillus',
#  'Gluconobacter',
#  'Gordonia',
#  'Haemophilus',
#  'Hafnia',
#  'Haloarcula',
#  'Halobacterium',
#  'Haloferax',
#  'Halogeometricum',
#  'Halomonas',
#  'Halorubrum',
#  'Hamiltonella',
#  'Helicobacter',
#  'Host',
#  'Hydrogenobaculum',
#  'Iodobacter',
#  'Klebsiella',
#  'Kluyvera',
#  'Lactobacillus',
#  'Lactococcus',
#  'Leclercia',
#  'Lelliottia',
#  'Lentibacter',
#  'Leptospira',
#  'Leuconostoc',
#  'Liberibacter',
#  'Listeria',
#  'Listonella',
#  'Loktanella',
#  'Lysinibacillus',
#  'Mannheimia',
#  'Marinitoga',
#  'Marinobacter',
#  'Marinomonas',
#  'Mastigocladus',
#  'Meiothermus',
#  'Mesorhizobium',
#  'Metallosphaera',
#  'Methanobacterium',
#  'Methanocaldococcus',
#  'Methanosarcina',
#  'Methanothermobacter',
#  'Methylophilales',
#  'Microbacterium',
#  'Microcystis',
#  'Micromonospora',
#  'Moraxella',
#  'Morganella',
#  'Mycobacterium',
#  'Mycoplasma',
#  'Myxococcus',
#  'Natrialba',
#  'Natrinema',
#  'Nitratiruptor',
#  'Nitrincola',
#  'Nitrosopumilus',
#  'Nitrososphaera',
#  'Nocardia',
#  'Nodularia',
#  'Nonlabens',
#  'Nostoc',
#  'Ochrobactrum',
#  'Oenococcus',
#  'Paenibacillus',
#  'Pantoea',
#  'Parabacteroides',
#  'Paracoccus',
#  'Pasteurella',
#  'Pectinobacterium',
#  'Pectobacterium',
#  'Pediococcus',
#  'Pelagibaca',
#  'Pelagibacter',
#  'Peptoclostridium',
#  'Phaeobacter',
#  'Phormidium',
#  'Photobacterium',
#  'Planktothrix',
#  'Plesiomonas',
#  'Polaribacter',
#  'Pontimonas',
#  'Prevotella',
#  'Prochlorococcus',
#  'Propionibacterium',
#  'Protaetiibacter',
#  'Proteobacteria',
#  'Proteus',
#  'Providencia',
#  'Pseudanabaena',
#  'Pseudoalteromonas',
#  'Pseudomonas',
#  'Psychrobacillus',
#  'Psychrobacter',
#  'Puniceispirillum',
#  'Pyrobaculum',
#  'Pyrococcus',
#  'Ralstonia',
#  'Raoultella',
#  'Rathayibacter',
#  'Rheinheimera',
#  'Rhizobium',
#  'Rhodobacter',
#  'Rhodococcus',
#  'Rhodoferax',
#  'Rhodovulum',
#  'Riemerella',
#  'Roseburia',
#  'Roseobacter',
#  'Roseovarius',
#  'Rothia',
#  'Ruegeria',
#  'Saccharolobus',
#  'Saccharomonospora',
#  'Salinibacter',
#  'Salinivibrio',
#  'Salisaeta',
#  'Salmonella',
#  'Serratia',
#  'Shewanella',
#  'Shigella',
#  'Silicibacter',
#  'Sinorhizobium',
#  'Skermania',
#  'Sodalis',
#  'Sphaerotilus',
#  'Sphingobium',
#  'Sphingomonas',
#  'Spiroplasma',
#  'Sporosarcina',
#  'Staphylococcus',
#  'Stenotrophomonas',
#  'Streptococcus',
#  'Streptomyces',
#  'Stygiolobus',
#  'Sulfitobacter',
#  'Sulfolobales',
#  'Sulfolobus',
#  'Synechococcus',
#  'Tenacibaculum',
#  'Tetraselmis',
#  'Tetrasphaera',
#  'Thalassomonas',
#  'Thermoanaerobacterium',
#  'Thermobifida',
#  'Thermococcus',
#  'Thermoproteus',
#  'Thermus',
#  'Thiobacimonas',
#  'Tsukamurella',
#  'Unspecified',
#  'Verrucomicrobia',
#  'Vibrio',
#  'Virgibacillus',
#  'Weissella',
#  'Wolbachia',
#  'Xanthomonas',
#  'Xenohaliotis',
#  'Xylella',
#  'Yersinia'}

# %%
gtdb = read_gtdb()
gtdb
# Out:
#                  accession  ambiguous_bases  checkm_completeness  \
# 0       GB_GCA_000006155.2             1916                93.12
# 1       GB_GCA_000007385.1                0                99.82
# 2       GB_GCA_000008605.1               67               100.00
# 3       GB_GCA_000010565.1                0               100.00
# 4       GB_GCA_000013845.2                0               100.00
# ...                    ...              ...                  ...
# 191522  RS_GCF_902166935.1                0                99.62
# 191523  RS_GCF_902166945.1                0                99.94
# 191524  RS_GCF_902167295.1                0                99.51
# 191525  RS_GCF_902167305.1                0                99.51
# 191526  RS_GCF_902167325.1                0                99.51
#
#         checkm_contamination  checkm_marker_count  \
# 0                       0.00                 1171
# 1                       0.00                  481
# 2                       0.00                  235
# 3                       0.63                  295
# 4                       0.00                  332
# ...                      ...                  ...
# 191522                  0.09                 1312
# 191523                  0.72                 1162
# 191524                  0.00                  303
# 191525                  0.00                  303
# 191526                  0.00                  303
#
#                    checkm_marker_lineage  checkm_marker_set_count  \
# 0                   g__Bacillus (UID902)                      324
# 1       c__Gammaproteobacteria (UID4202)                      276
# 2           f__Spirochaetaceae (UID2512)                      124
# 3                p__Firmicutes (UID1022)                      158
# 4             o__Clostridiales (UID1375)                      124
# ...                                  ...                      ...
# 191522           g__Klebsiella (UID5140)                      336
# 191523   f__Enterobacteriaceae (UID5121)                      336
# 191524        p__Bacteroidetes (UID2591)                      203
# 191525        p__Bacteroidetes (UID2591)                      203
# 191526        p__Bacteroidetes (UID2591)                      203
#
#         checkm_strain_heterogeneity  coding_bases  coding_density  ...  \
# 0                               0.0       4305660       80.178992  ...
# 1                               0.0       4190634       84.805944  ...
# 2                               0.0       1048744       92.155875  ...
# 3                               0.0       2608397       86.217312  ...
# 4                               0.0       2428396       82.037966  ...
# ...                             ...           ...             ...  ...
# 191522                          0.0       4894244       87.293148  ...
# 191523                          0.0       5162721       86.540042  ...
# 191524                          0.0       5737447       90.122088  ...
# 191525                          0.0       5738096       90.147873  ...
# 191526                          0.0       5671443       90.098258  ...
#
#         trna_aa_count  trna_count  trna_selenocysteine_count    domain  \
# 0                  16          31                          0  Bacteria
# 1                  20          53                          0  Bacteria
# 2                  20          45                          0  Bacteria
# 3                  20          51                          1  Bacteria
# 4                  20          95                          1  Bacteria
# ...               ...         ...                        ...       ...
# 191522             20          87                          1  Bacteria
# 191523             20          86                          1  Bacteria
# 191524             20          58                          0  Bacteria
# 191525             20          58                          0  Bacteria
# 191526             20          59                          0  Bacteria
#
#                 phylum                class               order  \
# 0           Firmicutes              Bacilli          Bacillales
# 1       Proteobacteria  Gammaproteobacteria     Xanthomonadales
# 2        Spirochaetota         Spirochaetia      Treponematales
# 3         Firmicutes_B     Desulfotomaculia  Desulfotomaculales
# 4         Firmicutes_A           Clostridia       Clostridiales
# ...                ...                  ...                 ...
# 191522  Proteobacteria  Gammaproteobacteria    Enterobacterales
# 191523  Proteobacteria  Gammaproteobacteria    Enterobacterales
# 191524    Bacteroidota          Bacteroidia     Chitinophagales
# 191525    Bacteroidota          Bacteroidia     Chitinophagales
# 191526    Bacteroidota          Bacteroidia     Chitinophagales
#
#                     family          genus                          species
# 0            Bacillaceae_G     Bacillus_A             Bacillus_A anthracis
# 1         Xanthomonadaceae    Xanthomonas               Xanthomonas oryzae
# 2          Treponemataceae      Treponema               Treponema pallidum
# 3         Pelotomaculaceae  Pelotomaculum  Pelotomaculum thermopropionicum
# 4           Clostridiaceae  Clostridium_P        Clostridium_P perfringens
# ...                    ...            ...                              ...
# 191522  Enterobacteriaceae     Klebsiella            Klebsiella pneumoniae
# 191523  Enterobacteriaceae     Klebsiella            Klebsiella pneumoniae
# 191524    Chitinophagaceae   Chitinophaga          Chitinophaga pinensis_A
# 191525    Chitinophagaceae   Chitinophaga          Chitinophaga pinensis_A
# 191526    Chitinophagaceae   Chitinophaga          Chitinophaga pinensis_A
#
# [191527 rows x 117 columns]

# %%
for h in hosts:
    if

# %%
phyla = {}
for h in hosts:
    for ph in pd.unique(gtdb[gtdb['genus'] == h]['phylum']):
        phyla[ph] = phyla.get(ph, 0)+1
phyla
# Out:
# {'Firmicutes': 28,
#  'Proteobacteria': 92,
#  'Bacteroidota': 14,
#  'Cyanobacteria': 10,
#  'Actinobacteriota': 25,
#  'Campylobacterota': 3,
#  'Firmicutes_A': 7,
#  'Aquificota': 1,
#  'Fusobacteriota': 1,
#  'Deinococcota': 2,
#  'Thermotogota': 1,
#  'Verrucomicrobiota_A': 1,
#  'Bdellovibrionota': 1,
#  'Spirochaetota': 1,
#  'Myxococcota': 1}
